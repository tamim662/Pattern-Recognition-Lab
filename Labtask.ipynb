# %% [markdown]
# <a href="https://colab.research.google.com/github/tamim662/Pattern-Recognition-Lab/blob/master/Labtask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from Bio import SeqIO

fasta_sequences = SeqIO.parse(open("//content/drive/My Drive/data/A.thaliana5289_pos.fasta"),'fasta') 
file=open("/newfile/data4.fasta", "w")
i=0
for fasta in fasta_sequences:
     name, sequence = fasta.id, str(fasta.seq)
     print(name, sequence)
     file.write(">"+ str(i) + '|1|training\n'  + sequence + '\n')
     i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# +sample UGUUGGAAGAUAAAUCAGUGCUUAGAGGAAAAGGGUUGGUU
# +sample AAAUAUGUUAAUGUUUGGUGCCCAAAAUGUCAUUCCAUUCG
# +sample UCUACCGUCGCCGGCCUCUCCUUCUCUUCAUACACAACCUC
# +sample CGAAAAGAGACAAGAGAAAGCGAGAAGAGAAGCUAAUGGCA
# +sample GGGAGCGGACUUACUUUCCUCUGGAUUCCUUUGAUCACGAC
# +sample AUCUUGUCCUCAGUGCAAAACUCGUUACAAGCGCAUCAAAG
# +sample AGUAAUAAUGGGGAAAAAAACAAAUGGUGAUGUGAAGAAGC
# +sample UGACGAUGAUGCUGUUGAAGCCGAUGCUGAGAUGCCUCCCC
# +sample GCGACCACGACCUCUCGGACCACCUCUUCCACCGCCGCGAC
# +sample UCUCGCUUCUUCUCCUCUUACUCCGAUUGAACGAUUCCGGA
# +sample AGAAUGAAGUAGUUGAGAGUCAAGGUAUAAGGAUAAGGAGA
# +sample AUGAAAGCUGAGGAGUCGCACAGUUGGGGAGUAAUAGAUGA
# +sample AGCUCGGGCUAGGGACCGCGCGAAUGUGGAUGAAGGGUUUA
# +sample ACCUUCCAGCCUCUGAUGUUCAGCUUGCCUUCCAAGCCUAU
# +sample CUCCACAUCUUGGAACACUUCAUUUGGAUCUGUUCCUAUAU
# +sample GUGAAGCCCAAUGCUAUGAGCAUUACCCACACUCAUGUAAA
# +sample AUUUCCUCCAUAAGCUUCUUCAAUCUUUCCUCGAACUCUCC
# +sample GUUCCCUCGUCAGAAACUCCCAAGGUAGUAGAAGAAGAAGU
# ...

# %%
pip install pandas

# %%
pip install biopython

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
import pandas as pd 

data = pd.read_csv("/content/drive/My Drive/New folder/Extracted/1/kmer1.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    1  0.5833333333333334  ...  0.42105263157894735  0.2916666666666667
# 0  1            0.458333  ...             0.263158            0.416667
# 1  1            0.375000  ...             0.578947            0.250000
# 2  1            0.083333  ...             0.526316            0.291667
# 3  1            0.666667  ...             0.526316            0.125000
# 4  1            0.375000  ...             0.210526            0.625000
#
# [5 rows x 5 columns]

# %%
data.drop(["1"], axis = 1, inplace = True) 
data.head()
# Out:
#    0.5833333333333334  ...  0.2916666666666667
# 0            0.458333  ...            0.416667
# 1            0.375000  ...            0.250000
# 2            0.083333  ...            0.291667
# 3            0.666667  ...            0.125000
# 4            0.375000  ...            0.625000
#
# [5 rows x 4 columns]

# %%
import numpy as np
npy=data.to_numpy()
type(npy)
np.save('numpy/test',npy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-9d212fcc0941> in <module>()
#       2 npy=data.to_numpy()
#       3 type(npy)
# ----> 4 np.save('numpy/test',npy)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     539         if not file.endswith('.npy'):
#     540             file = file + '.npy'
# --> 541         fid = open(file, "wb")
#     542         own_fid = True
#     543
#
# FileNotFoundError: [Errno 2] No such file or directory: 'numpy/test.npy'
